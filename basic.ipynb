# %%
print("hello")
print("pragya")
# Out:
# hello
# pragya

# %%
x=5
y=7
z=5
print(id(x),id(y),id(z))
y=9
print(id(x),id(y),id(z))
# Out:
# 140722506847480 140722506847544 140722506847480
# 140722506847480 140722506847608 140722506847480

# %%
name=input("enter your name")
print (name)
age=int(input("enter your age"))
height=float(input("enter your height"))
print("my name",name,"age",age,"height",height)
# Out:
# ram
# my name ram age 28 height 27.0

# %%
length= int(input("enter length of rectangle"))
width= int(input("enter width of rectangle"))
print("areaof rectangle is",length*width)
# Out:
# area= 9

# %%
R=int(input("radius of circle"))
print("area of circle is",3.14*R*R,"circumfrance is",2*3.14*R)
# Out:
# area of circle is 78.5 circumfrance is 31.400000000000002

# %%
age=int(input("enter age"))
if age>=18:
    print("can vote")
else:
    print("can not vote")
# Out:
# can not vote

# %%
num=int(input("enter number for chacking"))
if num>0:
    print("positive")
elif num<0:
    print("nagative")
else:
    print("is zero")
# Out:
# nagative

# %%
num=int(input("enter number"))
if num%2==0:
    print("is even ")
else:
    print("is odd")
# Out:
# is odd

# %%
year=int(input("enter the year"))
if year%4==0 or year%400==0 and year%100!=0:
    print("is leap year")
else:
    print ("not a leap year")
# Out:
# not a leap year

# %%
m=int(input("enter month"))
if m<=5 and m>=3:
    print("is spring")
elif m<=8 and m>=6:
    print("summer")
elif m<=11 and m>=9:
    print("winter")
else:
    print("autumn")
# Out:
# winter

# %%
E=int(input("enter the bill"))
if E<=50:
    print("bill",E*0.50)
elif E>=51 and E<=150:
    print("bill" ,E*0.75)
elif E>150 and E>=250:
    print("bill ",E*1.20)
else:
    print("bill",E*1.50)
# Out:
# bill 52.5

# %%
num=int(input("enter number "))
if num%3==0 and num%5==0:
    print("is divisible")
else:
    print("is not divisible")
# Out:
# is not divisibal
